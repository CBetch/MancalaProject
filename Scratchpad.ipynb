# %%
from MancalaGame import Mancala
from MinimaxAI import MinimaxAI
from PlayGames import PlayGames

# %%
games = PlayGames("random", "random", 100)
results = games.play_games()
print(results)
# Out:
# Playing 100 games of random vs random...
# ...

# %%
games = PlayGames("minimax", "random", 1, verbose=True)
results = games.play_games()
print(results)
# Out:
# Playing 1 games of minimax vs random...
# {'status': [1], 'score': [(28, 20)], 'num_moves': [38]}

# %%
games = PlayGames("minimax", "minimax", 1, verbose=True)
results = games.play_games()
print(results)
# Out:
# Playing 1 games of minimax vs minimax...
# {'status': [1], 'score': [(28, 20)], 'num_moves': [38]}
